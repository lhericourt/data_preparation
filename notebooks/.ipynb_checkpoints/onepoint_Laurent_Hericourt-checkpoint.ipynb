# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # 0 - Pre-processing

# %%
# Import of supplier file
SUPPLIER_DATA_PATH = "/Users/lolo/Développement/Python/onepoint/data/supplier_car.json"
with open(SUPPLIER_DATA_PATH) as f:
    supplier_data_str = f.readlines()
supplier_data_json = [json.loads(x.strip()) for x in supplier_data_str]

# %%
# Load supplier data into a dataframe
supplier_data = pd.DataFrame(supplier_data_json)
supplier_data = supplier_data.sort_values(by="ID")
supplier_data.head(120)
# Out:
#              Attribute Names Attribute Values      ID       MakeText  \
# 20141  ConsumptionRatingText             null     1.0  MERCEDES-BENZ
# 4577       ConditionTypeText         Occasion     1.0  MERCEDES-BENZ
# 4364    TransmissionTypeText          Automat     1.0  MERCEDES-BENZ
# 19538                    Ccm             3199     1.0  MERCEDES-BENZ
# 7573            BodyTypeText        Limousine     1.0  MERCEDES-BENZ
# 14900                     Hp              224     1.0  MERCEDES-BENZ
# 5272           DriveTypeText           Allrad     1.0  MERCEDES-BENZ
# 10374             Properties         "Ab MFK"     1.0  MERCEDES-BENZ
# 10902          BodyColorText        anthrazit     1.0  MERCEDES-BENZ
# 3622                      Km            31900     1.0  MERCEDES-BENZ
# 18578                  Seats                5     1.0  MERCEDES-BENZ
# 16139   ConsumptionTotalText     11.5 l/100km     1.0  MERCEDES-BENZ
# 9760            FirstRegYear             1999     1.0  MERCEDES-BENZ
# 6027                   Doors                4     1.0  MERCEDES-BENZ
# 21164        Co2EmissionText         275 g/km     1.0  MERCEDES-BENZ
# 10936          FirstRegMonth                1     1.0  MERCEDES-BENZ
# 5931                    City           Zuzwil     1.0  MERCEDES-BENZ
# 16778           FuelTypeText           Benzin     1.0  MERCEDES-BENZ
# 8139       InteriorColorText             grau     1.0  MERCEDES-BENZ
# 13374                  Seats                4    10.0    LAMBORGHINI
# 15057        Co2EmissionText             null    10.0    LAMBORGHINI
# 6916                   Doors                2    10.0    LAMBORGHINI
# 2092                    City           Zuzwil    10.0    LAMBORGHINI
# 20074                    Ccm             3929    10.0    LAMBORGHINI
# 6349   ConsumptionRatingText             null    10.0    LAMBORGHINI
# 11586                     Km            48000    10.0    LAMBORGHINI
# 9527       ConditionTypeText         Oldtimer    10.0    LAMBORGHINI
# 8116                      Hp              350    10.0    LAMBORGHINI
# 8782            BodyTypeText            Coupé    10.0    LAMBORGHINI
# 12094           FuelTypeText           Benzin    10.0    LAMBORGHINI
# ...                      ...              ...     ...            ...
# 21673                  Doors                2  1001.0            BMW
# 5343            FirstRegYear             1974  1001.0            BMW
# 12128                   City           Zuzwil  1001.0            BMW
# 16708          BodyColorText      silber mét.  1001.0            BMW
# 13009          FirstRegMonth                3  1001.0            BMW
# 19845   TransmissionTypeText             null  1002.0         DATSUN
# 2107           BodyColorText      silber mét.  1002.0         DATSUN
# 18239   ConsumptionTotalText             null  1002.0         DATSUN
# 20765  ConsumptionRatingText             null  1002.0         DATSUN
# 6813                    City           Zuzwil  1002.0         DATSUN
# 16706           BodyTypeText        Cabriolet  1002.0         DATSUN
# 18086          DriveTypeText             null  1002.0         DATSUN
# 16928                  Doors                2  1002.0         DATSUN
# 14815                     Km            23300  1002.0         DATSUN
# 13479                     Hp              143  1002.0         DATSUN
# 11457           FuelTypeText           Benzin  1002.0         DATSUN
# 8232           FirstRegMonth                7  1002.0         DATSUN
# 2745              Properties         "Ab MFK"  1002.0         DATSUN
# 7239                     Ccm             2000  1002.0         DATSUN
# 9285       InteriorColorText          schwarz  1002.0         DATSUN
# 6662       ConditionTypeText         Occasion  1002.0         DATSUN
# 13195        Co2EmissionText             null  1002.0         DATSUN
# 20132                  Seats                2  1002.0         DATSUN
# 19721           FirstRegYear             1969  1002.0         DATSUN
# 5148                     Ccm             4172  1003.0           AUDI
# 8394              Properties         "Ab MFK"  1003.0           AUDI
# 4861            FuelTypeText           Benzin  1003.0           AUDI
# 8256   ConsumptionRatingText             null  1003.0           AUDI
# 19439                     Km            66300  1003.0           AUDI
# 19374      ConditionTypeText         Occasion  1003.0           AUDI
#
#       ModelText           ModelTypeText                TypeName  \
# 20141     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 4577      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 4364      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 19538     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 7573      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 14900     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 5272      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 10374     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 10902     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 3622      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 18578     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 16139     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 9760      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 6027      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 21164     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 10936     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 5931      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 16778     E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 8139      E 320  E 320 Elégance 4-Matic  E 320 Elégance 4-Matic
# 13374      None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 15057      None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 6916       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 2092       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 20074      None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 6349       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 11586      None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 9527       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 8116       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 8782       None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# 12094      None   Espada GT 400 Serie 3   Espada GT 400 Serie 3
# ...         ...                     ...                     ...
# 21673      2002              2002 Turbo                   Turbo
# 5343       2002              2002 Turbo                   Turbo
# 12128      2002              2002 Turbo                   Turbo
# 16708      2002              2002 Turbo                   Turbo
# 13009      2002              2002 Turbo                   Turbo
# 19845      None             SPORTS 2000             SPORTS 2000
# 2107       None             SPORTS 2000             SPORTS 2000
# 18239      None             SPORTS 2000             SPORTS 2000
# 20765      None             SPORTS 2000             SPORTS 2000
# 6813       None             SPORTS 2000             SPORTS 2000
# 16706      None             SPORTS 2000             SPORTS 2000
# 18086      None             SPORTS 2000             SPORTS 2000
# 16928      None             SPORTS 2000             SPORTS 2000
# 14815      None             SPORTS 2000             SPORTS 2000
# 13479      None             SPORTS 2000             SPORTS 2000
# 11457      None             SPORTS 2000             SPORTS 2000
# 8232       None             SPORTS 2000             SPORTS 2000
# 2745       None             SPORTS 2000             SPORTS 2000
# 7239       None             SPORTS 2000             SPORTS 2000
# 9285       None             SPORTS 2000             SPORTS 2000
# 6662       None             SPORTS 2000             SPORTS 2000
# 13195      None             SPORTS 2000             SPORTS 2000
# 20132      None             SPORTS 2000             SPORTS 2000
# 19721      None             SPORTS 2000             SPORTS 2000
# 5148         A8          A8 4.2 quattro          A8 4.2 quattro
# 8394         A8          A8 4.2 quattro          A8 4.2 quattro
# 4861         A8          A8 4.2 quattro          A8 4.2 quattro
# 8256         A8          A8 4.2 quattro          A8 4.2 quattro
# 19439        A8          A8 4.2 quattro          A8 4.2 quattro
# 19374        A8          A8 4.2 quattro          A8 4.2 quattro
#
#                                TypeNameFull  \
# 20141  MERCEDES-BENZ E 320 Elégance 4-Matic
# 4577   MERCEDES-BENZ E 320 Elégance 4-Matic
# 4364   MERCEDES-BENZ E 320 Elégance 4-Matic
# 19538  MERCEDES-BENZ E 320 Elégance 4-Matic
# 7573   MERCEDES-BENZ E 320 Elégance 4-Matic
# 14900  MERCEDES-BENZ E 320 Elégance 4-Matic
# 5272   MERCEDES-BENZ E 320 Elégance 4-Matic
# 10374  MERCEDES-BENZ E 320 Elégance 4-Matic
# 10902  MERCEDES-BENZ E 320 Elégance 4-Matic
# 3622   MERCEDES-BENZ E 320 Elégance 4-Matic
# 18578  MERCEDES-BENZ E 320 Elégance 4-Matic
# 16139  MERCEDES-BENZ E 320 Elégance 4-Matic
# 9760   MERCEDES-BENZ E 320 Elégance 4-Matic
# 6027   MERCEDES-BENZ E 320 Elégance 4-Matic
# 21164  MERCEDES-BENZ E 320 Elégance 4-Matic
# 10936  MERCEDES-BENZ E 320 Elégance 4-Matic
# 5931   MERCEDES-BENZ E 320 Elégance 4-Matic
# 16778  MERCEDES-BENZ E 320 Elégance 4-Matic
# 8139   MERCEDES-BENZ E 320 Elégance 4-Matic
# 13374     LAMBORGHINI Espada GT 400 Serie 3
# 15057     LAMBORGHINI Espada GT 400 Serie 3
# 6916      LAMBORGHINI Espada GT 400 Serie 3
# 2092      LAMBORGHINI Espada GT 400 Serie 3
# 20074     LAMBORGHINI Espada GT 400 Serie 3
# 6349      LAMBORGHINI Espada GT 400 Serie 3
# 11586     LAMBORGHINI Espada GT 400 Serie 3
# 9527      LAMBORGHINI Espada GT 400 Serie 3
# 8116      LAMBORGHINI Espada GT 400 Serie 3
# 8782      LAMBORGHINI Espada GT 400 Serie 3
# 12094     LAMBORGHINI Espada GT 400 Serie 3
# ...                                     ...
# 21673                        BMW 2002 Turbo
# 5343                         BMW 2002 Turbo
# 12128                        BMW 2002 Turbo
# 16708                        BMW 2002 Turbo
# 13009                        BMW 2002 Turbo
# 19845                    DATSUN SPORTS 2000
# 2107                     DATSUN SPORTS 2000
# 18239                    DATSUN SPORTS 2000
# 20765                    DATSUN SPORTS 2000
# 6813                     DATSUN SPORTS 2000
# 16706                    DATSUN SPORTS 2000
# 18086                    DATSUN SPORTS 2000
# 16928                    DATSUN SPORTS 2000
# 14815                    DATSUN SPORTS 2000
# 13479                    DATSUN SPORTS 2000
# 11457                    DATSUN SPORTS 2000
# 8232                     DATSUN SPORTS 2000
# 2745                     DATSUN SPORTS 2000
# 7239                     DATSUN SPORTS 2000
# 9285                     DATSUN SPORTS 2000
# 6662                     DATSUN SPORTS 2000
# 13195                    DATSUN SPORTS 2000
# 20132                    DATSUN SPORTS 2000
# 19721                    DATSUN SPORTS 2000
# 5148                    AUDI A8 4.2 quattro
# 8394                    AUDI A8 4.2 quattro
# 4861                    AUDI A8 4.2 quattro
# 8256                    AUDI A8 4.2 quattro
# 19439                   AUDI A8 4.2 quattro
# 19374                   AUDI A8 4.2 quattro
#
#                                   entity_id
# 20141  afa1558b-2aa4-4c2b-a2aa-3d4019692c55
# 4577   5b6a7cc2-aeae-49cf-86c1-fba26fc716ea
# 4364   36daa856-57a4-4472-b6c5-c166238e6160
# 19538  441cb3e8-1472-48df-91ae-23c0d99c05bb
# 7573   891fd11f-0bc6-4eec-b398-ba58d89488a9
# 14900  e7f35ba6-9fd8-41d5-b3ac-3e4aab9f2b80
# 5272   de4d0e42-5c4a-4991-84eb-e08cdd5afc30
# 10374  96475beb-91f8-4d48-9c94-a06b017dde1e
# 10902  004320f3-d639-47e3-8666-b300991f0af8
# 3622   aa431da6-c684-40fb-9951-5eb4a6db553b
# 18578  94298e0f-4e8e-471b-9269-867358a96df7
# 16139  ce82f554-ef3a-4dd5-8788-aa561e88ad5a
# 9760   23da7638-7f1b-43ad-8021-4dcd67c81439
# 6027   63ecf167-2cea-4231-90d9-b9dab5558aee
# 21164  6f9edd6f-ea2a-4d9b-a040-03f26282950e
# 10936  073ea3c0-9010-48c1-82cc-c9b5dc6d447e
# 5931   5267500a-65ef-496e-a5fc-49e74baee81b
# 16778  46d15b71-0afe-469b-ab9c-9b011205611b
# 8139   f23ba3d3-699a-43f3-94f2-1d06a3f961d0
# 13374  c8a1a1e6-0d2c-4add-897c-7247b4a18677
# 15057  0534fbb9-4455-4e05-9e7f-e1f4662c04db
# 6916   0f3acd19-1863-4a27-9529-3be7e3cf0d4a
# 2092   8c64a0bb-b462-4dc3-b3fa-120a33951969
# 20074  a39fe8dc-4569-409e-93db-d2926249993b
# 6349   a0edd921-f9de-4a78-82ca-35cb0d328967
# 11586  80a4abc3-dab3-42c4-8b91-1b2ada527066
# 9527   fb2ae924-77c0-4254-9a35-b052114dd1da
# 8116   ed2115f1-c391-4194-8dc2-611a7e651ca0
# 8782   68e0ae7c-2654-4897-b7f3-ca49c9cb3be0
# 12094  e06ab338-a075-4d19-afb5-a77113ec44f5
# ...                                     ...
# 21673  cdbc4eee-342a-4fc7-ab74-6a9d47f36835
# 5343   ea8899e9-e154-430a-9906-df1b4a347121
# 12128  e680885a-07d1-4229-b4a1-58833a09ad68
# 16708  3bd0c13d-5867-4a95-98f4-7a30c5a63489
# 13009  86f94baa-8ca0-490b-978d-d1cb23ace6d1
# 19845  7c35bd6a-cd30-48af-84a9-91692ccfd2b7
# 2107   9042d24e-ea2e-49d8-846c-9b86d6c73899
# 18239  57536b21-78c5-4452-8526-a5e77917de88
# 20765  25314bf7-01ad-43b6-be2e-04d3a21f20af
# 6813   fb19a41c-bba7-49d6-b6a0-54aad42610a2
# 16706  3b9f3220-b063-459e-8fa8-7c29ef470434
# 18086  3d91f39b-aece-4f4b-8ba7-bae83fbf4775
# 16928  62c93d60-54d8-40d5-8d49-4cc0ae74a3fc
# 14815  d7f93725-297a-47b1-b62e-5ad51d9dd134
# 13479  ddc742dd-1912-4321-8701-930112b033e3
# 11457  6af44b3f-f662-4144-804e-6f4abf91d9d2
# 8232   035a0dbf-f206-45f3-ae52-bae2ba8d9914
# 2745   018b4451-ebc7-4de4-bd68-8c78ef13c50f
# 7239   4cdf825e-6fa0-48ef-928f-5243eeb26825
# 9285   cb7c6c7c-d4d1-4172-933d-02d95302bb89
# 6662   df01b6fa-47a4-473b-9d8f-2eea8639153a
# 13195  a5fceeb8-3667-445e-a991-4a6f20ef4642
# 20132  ae02973f-aeaf-447f-a640-c4e196e65ccb
# 19721  61e9b181-99dd-4ef3-851e-243e6fe9616c
# 5148   c81ae135-1d54-4d12-b3e5-2499af75e31f
# 8394   1ff38db8-4942-49c0-ab09-b2b867c8150c
# 4861   8ed78aa6-ea25-4e4a-9a3a-318f52d0fa02
# 8256   07753c4f-41e2-48f8-ae83-36ec24294bbb
# 19439  31f76bf0-c9bb-4a42-ab26-0e45589d6908
# 19374  25915ee3-5e55-4129-885c-070ae000593a
#
# [120 rows x 9 columns]

# %%
# Set the values of column "Attribute Names" as different columns : one column per value 
supplier_data_as_table = supplier_data.pivot_table(index=["ID", "MakeText", "ModelText", "ModelTypeText", "TypeName", "TypeNameFull"], columns="Attribute Names", values="Attribute Values", aggfunc='first').reset_index()
#supplier_data_as_table.index.rename('Index', inplace=True).reset_index()

supplier_data_as_table.head()
# Out:
# Attribute Names      ID       MakeText ModelText           ModelTypeText  \
# 0                   1.0  MERCEDES-BENZ     E 320  E 320 Elégance 4-Matic
# 1                 100.0        FERRARI      F360  F360 Modena Berlinetta
# 2                1000.0     ALFA ROMEO        8C                      8C
# 3                1001.0            BMW      2002              2002 Turbo
# 4                1003.0           AUDI        A8          A8 4.2 quattro
#
# Attribute Names                TypeName                          TypeNameFull  \
# 0                E 320 Elégance 4-Matic  MERCEDES-BENZ E 320 Elégance 4-Matic
# 1                F360 Modena Berlinetta        FERRARI F360 Modena Berlinetta
# 2                                  null                         ALFA ROMEO 8C
# 3                                 Turbo                        BMW 2002 Turbo
# 4                        A8 4.2 quattro                   AUDI A8 4.2 quattro
#
# Attribute Names BodyColorText BodyTypeText   Ccm        City  \
# 0                   anthrazit    Limousine  3199      Zuzwil
# 1                   blau mét.        Coupé  3586      Zuzwil
# 2                 silber mét.    Cabriolet  4691  Porrentruy
# 3                 silber mét.    Limousine  1977      Zuzwil
# 4                 silber mét.    Limousine  4172      Zuzwil
#
# Attribute Names               ...                   DriveTypeText  \
# 0                             ...                          Allrad
# 1                             ...                Hinterradantrieb
# 2                             ...                Hinterradantrieb
# 3                             ...                Hinterradantrieb
# 4                             ...                          Allrad
#
# Attribute Names FirstRegMonth FirstRegYear FuelTypeText   Hp  \
# 0                           1         1999       Benzin  224
# 1                           2         2004       Benzin  400
# 2                           4         2011       Benzin  450
# 3                           3         1974       Benzin  170
# 4                           1         1997       Benzin  300
#
# Attribute Names InteriorColorText     Km Properties Seats  \
# 0                            grau  31900   "Ab MFK"     5
# 1                           beige  42600   "Ab MFK"     2
# 2                         schwarz  23900   "Ab MFK"     0
# 3                         schwarz  97100   "Ab MFK"     4
# 4                         schwarz  66300   "Ab MFK"     5
#
# Attribute Names            TransmissionTypeText
# 0                                       Automat
# 1                Automatisiertes Schaltgetriebe
# 2                            Automatik-Getriebe
# 3                                Schaltgetriebe
# 4                                       Automat
#
# [5 rows x 25 columns]

# %%
# Replace value "null" by the pandas null value : Nan
supplier_data_as_table = supplier_data_as_table.replace("null", np.nan)
supplier_data_as_table.head()
# Out:
# Attribute Names      ID       MakeText ModelText           ModelTypeText  \
# 0                   1.0  MERCEDES-BENZ     E 320  E 320 Elégance 4-Matic
# 1                 100.0        FERRARI      F360  F360 Modena Berlinetta
# 2                1000.0     ALFA ROMEO        8C                      8C
# 3                1001.0            BMW      2002              2002 Turbo
# 4                1003.0           AUDI        A8          A8 4.2 quattro
#
# Attribute Names                TypeName                          TypeNameFull  \
# 0                E 320 Elégance 4-Matic  MERCEDES-BENZ E 320 Elégance 4-Matic
# 1                F360 Modena Berlinetta        FERRARI F360 Modena Berlinetta
# 2                                   NaN                         ALFA ROMEO 8C
# 3                                 Turbo                        BMW 2002 Turbo
# 4                        A8 4.2 quattro                   AUDI A8 4.2 quattro
#
# Attribute Names BodyColorText BodyTypeText   Ccm        City  \
# 0                   anthrazit    Limousine  3199      Zuzwil
# 1                   blau mét.        Coupé  3586      Zuzwil
# 2                 silber mét.    Cabriolet  4691  Porrentruy
# 3                 silber mét.    Limousine  1977      Zuzwil
# 4                 silber mét.    Limousine  4172      Zuzwil
#
# Attribute Names               ...                   DriveTypeText  \
# 0                             ...                          Allrad
# 1                             ...                Hinterradantrieb
# 2                             ...                Hinterradantrieb
# 3                             ...                Hinterradantrieb
# 4                             ...                          Allrad
#
# Attribute Names FirstRegMonth FirstRegYear FuelTypeText   Hp  \
# 0                           1         1999       Benzin  224
# 1                           2         2004       Benzin  400
# 2                           4         2011       Benzin  450
# 3                           3         1974       Benzin  170
# 4                           1         1997       Benzin  300
#
# Attribute Names InteriorColorText     Km Properties Seats  \
# 0                            grau  31900   "Ab MFK"     5
# 1                           beige  42600   "Ab MFK"     2
# 2                         schwarz  23900   "Ab MFK"     0
# 3                         schwarz  97100   "Ab MFK"     4
# 4                         schwarz  66300   "Ab MFK"     5
#
# Attribute Names            TransmissionTypeText
# 0                                       Automat
# 1                Automatisiertes Schaltgetriebe
# 2                            Automatik-Getriebe
# 3                                Schaltgetriebe
# 4                                       Automat
#
# [5 rows x 25 columns]

# %% [markdown]
# # 1 - Data normalization
#
# ##  Value analysis

# %%
supplier_data_as_table.describe()
# Out:
# Attribute Names     ID       MakeText ModelText      ModelTypeText  \
# count             1103           1103      1103               1103
# unique            1103             56       290                548
# top              215.0  MERCEDES-BENZ       911  RS6 Avant quattro
# freq                 1            285        95                 31
#
# Attribute Names           TypeName            TypeNameFull BodyColorText  \
# count                         1087                    1103          1103
# unique                         530                     548            29
# top              RS6 Avant quattro  AUDI RS6 Avant quattro  schwarz mét.
# freq                            31                      31           223
#
# Attribute Names BodyTypeText   Ccm    City         ...           \
# count                   1103  1103    1103         ...
# unique                     9   245       6         ...
# top                    Coupé  4172  Zuzwil         ...
# freq                     348    51    1072         ...
#
# Attribute Names     DriveTypeText FirstRegMonth FirstRegYear FuelTypeText  \
# count                        1079          1103         1103         1089
# unique                          3            13           53            4
# top              Hinterradantrieb             3         2002       Benzin
# freq                          688           140           94         1059
#
# Attribute Names    Hp InteriorColorText    Km Properties Seats  \
# count            1103              1037  1103       1034  1103
# unique            204                12   711          6     8
# top               450           schwarz  5000   "Ab MFK"     5
# freq               49               561     7        959   473
#
# Attribute Names TransmissionTypeText
# count                           1093
# unique                             8
# top                          Automat
# freq                             306
#
# [4 rows x 25 columns]

# %%
for col in supplier_data_as_table.columns:
    if col != "ID":
        print("#######################################################")
        print("Different values and count for column : {}".format(col))
        print("Number of unique values : {}".format(len(supplier_data_as_table[col].unique())))
        print(supplier_data_as_table[col].value_counts())
# Out:
# #######################################################
# Different values and count for column : MakeText
# Number of unique values : 56
# MERCEDES-BENZ    285
# PORSCHE          137
# BMW              124
# AUDI             118
# FERRARI           68
# RENAULT           45
# LAMBORGHINI       36
# BENTLEY           34
# MASERATI          32
# VW                19
# LAND ROVER        17
# ASTON MARTIN      15
# JAGUAR            15
# TOYOTA            13
# CHEVROLET         12
# ROLLS-ROYCE       11
# BMW-ALPINA        11
# ALFA ROMEO        10
# FIAT               6
# FORD               6
# NISSAN             6
# LOTUS              6
# McLAREN            6
# OPEL               5
# VOLVO              4
# FORD (USA)         4
# TRIUMPH            4
# CHRYSLER           4
# SAAB               4
# LANCIA             4
# MITSUBISHI         3
# MAZDA              3
# JEEP               3
# DODGE              3
# CITROEN            2
# HONDA              2
# LINCOLN            2
# MG                 2
# HUMMER             2
# PEUGEOT            2
# SEAT               2
# DAIMLER            2
# LEXUS              1
# WIESMANN           1
# BUGATTI            1
# AUTOBIANCHI        1
# SMART              1
# MINI               1
# TALBOT             1
# MORGAN             1
# DE TOMASO          1
# HYUNDAI            1
# SUBARU             1
# DATSUN             1
# DAEWOO             1
# DAIHATSU           1
# Name: MakeText, dtype: int64
# #######################################################
# Different values and count for column : ModelText
# Number of unique values : 290
# 911              95
# RS6              58
# SL 500           33
# CAYENNE          27
# SL 600           21
# SL 55 AMG        18
# ALPINE           18
# A8               17
# M5               16
# F360             15
# CONTINENTAL      15
# S 500            14
# X5               14
# Alpine A110      14
# ARNAGE           13
# QUATTROPORTE     13
# M3               12
# CL 600           12
# RANGE ROVER      12
# DIABLO           11
# RS4              11
# MURCIÉLAGO       10
# GALLARDO         10
# CORVETTE         10
# S 65 AMG         10
# PHAETON           9
# 456               9
# CL 500            9
# E 55 AMG          9
# 575M              9
#                  ..
# V70               1
# VECTRA            1
# X1                1
# PUNTO             1
# CHARADE           1
# ALFASUD           1
# 545               1
# GRANSPORT         1
# BITURBO           1
# C70               1
# 745               1
# 760               1
# 2CV               1
# FRONTERA          1
# 550               1
# CLS 350           1
# Silver Shadow     1
# SLK 32 AMG        1
# IBIZA             1
# SLK 320           1
# S 350             1
# MINI              1
# EOS               1
# 166               1
# 205               1
# GHIBLI            1
# MATRA             1
# C 43 AMG          1
# Ram               1
# Cabriolet         1
# Name: ModelText, dtype: int64
# #######################################################
# Different values and count for column : ModelTypeText
# Number of unique values : 548
# RS6 Avant quattro                31
# 911 Turbo                        30
# SL 500                           30
# RS6 Avant 5.0 V10 quattro        23
# SL 600                           21
# Cayenne Turbo                    18
# SL 55 AMG                        18
# M5                               16
# A8 4.2 quattro                   15
# CL 600                           12
# M3                               10
# X5 4.4i                           9
# Alpine A310 V6                    9
# E 55 AMG Avantgarde               9
# F360 Modena Berlinetta            9
# M6                                8
# S 500                             8
# Coupé GT                          8
# S 65 AMG L                        8
# 575M                              8
# CL 500                            7
# 911 GT2                           7
# Range Rover 4.6 HSE               7
# Quattroporte 4.2                  7
# CLS 500                           7
# 740i                              6
# F355 Berlinetta                   6
# SL 320                            6
# 911 Carrera                       6
# Phaeton 6.0 W12 4Motion           6
#                                  ..
# 365 Daytona Plexiglas             1
# 540i Touring                      1
# E 320 Avantgarde                  1
# E E-Type III                      1
# Impreza 2.5T WRX                  1
# Stilo 1.8 16V Swiss               1
# 599 GTB HGTE                      1
# F550 Maranello                    1
# 528i Touring                      1
# Z4 M Coupé                        1
# Range Rover 4.4TD Vogue           1
# 330i                              1
# 2CV6 Charleston                   1
# S5 Coupé 4.2 FSI quattro          1
# 9-3 2.0i-16 T SE                  1
# Range Rover 5.0 V8 SC             1
# 911 Turbo S                       1
# C 63 AMG BLACK SERIES (Coupé)     1
# A4 Avant 2.8 q.Ambition           1
# C5 3.0 V6 Exclusive               1
# RS4 Cabriolet 4.2 quattro         1
# 135i                              1
# CORNICHE Convertible              1
# DELTA Integrale EVO               1
# TT Roadster 1.8 T                 1
# S 400 CDI                         1
# LAND CRUISER BJ 40 LT             1
# 730i                              1
# Charade 1.0 Turbo                 1
# Cabriolet 2.8 E                   1
# Name: ModelTypeText, dtype: int64
# #######################################################
# Different values and count for column : TypeName
# Number of unique values : 531
# RS6 Avant quattro            31
# SL 500                       30
# 911 Turbo                    29
# RS6 Avant 5.0 V10 quattro    23
# SL 600                       21
# Cayenne Turbo                18
# SL 55 AMG                    18
# M5                           16
# A8 4.2 quattro               15
# CL 600                       12
# M3                           10
# Alpine A310 V6                9
# F360 Modena Berlinetta        9
# E 55 AMG Avantgarde           9
# X5 4.4i                       9
# Turbo                         9
# S 65 AMG L                    8
# S 500                         8
# Coupé GT                      8
# M6                            8
# 575M                          8
# CL 500                        7
# CLS 500                       7
# Quattroporte 4.2              7
# Range Rover 4.6 HSE           7
# 911 GT2                       7
# Phaeton 6.0 W12 4Motion       6
# 911 Carrera                   6
# F355 Berlinetta               6
# 740i                          6
#                              ..
# 5.0 GT Premium 50 Years       1
# S3 2.0 TFSI quattro           1
# E 320 Avantgarde              1
# Sunny 2.0 16V GTI-R           1
# Charade 1.0 Turbo             1
# 730i                          1
# Range Rover 4.4TD Vogue       1
# S5 Coupé 4.2 FSI quattro      1
# 525i                          1
# 330i                          1
# 9-3 2.0i-16 T SE              1
# Range Rover 5.0 V8 SC         1
# Impreza 2.5T WRX              1
# 110 GT/SS                     1
# 911 Turbo S                   1
# A4 Avant 2.8 q.Ambition       1
# II                            1
# RS4 Cabriolet 4.2 quattro     1
# 2CV6 Charleston               1
# 135i                          1
# CSL                           1
# E21                           1
# Windschutzscheibe             1
# 32 V                          1
# CSA                           1
# New Beetle Cup                1
# TT Roadster 1.8 T             1
# S 400 CDI                     1
# 6.0 AMG                       1
# Cabriolet 2.8 E               1
# Name: TypeName, dtype: int64
# #######################################################
# Different values and count for column : TypeNameFull
# Number of unique values : 548
# AUDI RS6 Avant quattro                        31
# PORSCHE 911 Turbo                             30
# MERCEDES-BENZ SL 500                          30
# AUDI RS6 Avant 5.0 V10 quattro                23
# MERCEDES-BENZ SL 600                          21
# PORSCHE Cayenne Turbo                         18
# MERCEDES-BENZ SL 55 AMG                       18
# BMW M5                                        16
# AUDI A8 4.2 quattro                           15
# MERCEDES-BENZ CL 600                          12
# BMW M3                                        10
# RENAULT Alpine A310 V6                         9
# BMW X5 4.4i                                    9
# MERCEDES-BENZ E 55 AMG Avantgarde              9
# FERRARI F360 Modena Berlinetta                 9
# BMW M6                                         8
# MASERATI Coupé GT                              8
# MERCEDES-BENZ S 65 AMG L                       8
# FERRARI 575M                                   8
# MERCEDES-BENZ S 500                            8
# MERCEDES-BENZ CL 500                           7
# LAND ROVER Range Rover 4.6 HSE                 7
# MERCEDES-BENZ CLS 500                          7
# MASERATI Quattroporte 4.2                      7
# PORSCHE 911 GT2                                7
# FERRARI F355 Berlinetta                        6
# PORSCHE 911 Carrera                            6
# MERCEDES-BENZ SL 320                           6
# PORSCHE 911 Carrera Cabrio                     6
# VW Phaeton 6.0 W12 4Motion                     6
#                                               ..
# BMW 540i Touring                               1
# MERCEDES-BENZ S 400 CDI                        1
# BMW 530d GT                                    1
# PORSCHE 911 Carrera Jubilé 40                  1
# ASTON MARTIN DB7 Vantage Volante               1
# LAND ROVER Discovery 3.9                       1
# ALFA ROMEO GT 1300 Junior                      1
# MERCEDES-BENZ S 350 L 4Matic                   1
# MERCEDES-BENZ C 230 Elégance                   1
# OPEL Speedster 2.2 16V                         1
# DATSUN 280 ZX                                  1
# ROLLS-ROYCE CORNICHE Cabrio                    1
# FERRARI Dino 246 GTS                           1
# LAMBORGHINI DIABLO SV-R Race                   1
# FORD (USA) Mustang 5.0 GT Premium 50 Years     1
# AUDI TTS Cpé 2.0 TFSI quattro                  1
# DODGE VIPER                                    1
# FERRARI F355 GTS                               1
# SUBARU Impreza 2.5T WRX                        1
# MERCEDES-BENZ E 350 Elégance 4Matic            1
# LAMBORGHINI Gallardo 5.0 V10 Coupé             1
# FERRARI F430 Challenge GT3 LOOK                1
# TOYOTA LAND CRUISER BJ 40 LT                   1
# NISSAN SUNNY 2.0 16V GTI-R Rallye              1
# BMW-ALPINA 5 SERIES B7 (E28)                   1
# PORSCHE 911 Carrera 2 RS                       1
# MERCEDES-BENZ C 63 AMG Avantgarde              1
# VOLVO S40 2.0 T                                1
# NISSAN Sunny 2.0 16V GTI-R                     1
# RENAULT Alpine A110 Modell 1400 FASA           1
# Name: TypeNameFull, dtype: int64
# #######################################################
# Different values and count for column : BodyColorText
# Number of unique values : 29
# schwarz mét.      223
# silber mét.       200
# blau mét.         108
# grau mét.          98
# schwarz            92
# weiss              62
# rot                58
# grün mét.          45
# blau               39
# anthrazit mét.     29
# silber             28
# grau               28
# gelb               19
# grün               15
# weiss mét.         12
# bordeaux mét.      10
# rot mét.            7
# anthrazit           5
# violett mét.        5
# beige mét.          4
# gold mét.           3
# bordeaux            3
# braun mét.          2
# orange mét.         2
# orange              2
# gelb mét.           1
# braun               1
# beige               1
# gold                1
# Name: BodyColorText, dtype: int64
# #######################################################
# Different values and count for column : BodyTypeText
# Number of unique values : 9
# Coupé                   348
# Limousine               313
# Cabriolet               236
# Kombi                    98
# SUV / Geländewagen       88
# Kleinwagen               12
# Kompaktvan / Minivan      4
# Pick-up                   3
# Sattelschlepper           1
# Name: BodyTypeText, dtype: int64
# #######################################################
# Different values and count for column : Ccm
# Number of unique values : 245
# 4172    51
# 3600    51
# 5439    47
# 4966    38
# 4398    26
# 4244    26
# 4991    25
# 5998    21
# 5513    19
# 3199    19
# 5461    18
# 6209    18
# 4511    18
# 5981    17
# 4971    16
# 4999    15
# 3586    15
# 5748    14
# 4806    14
# 3996    13
# 3387    13
# 5204    12
# 5984    12
# 4973    12
# 4163    12
# 6761    11
# 5707    10
# 5474    10
# 2664    10
# 2979    10
#         ..
# 4951     1
# 602      1
# 5752     1
# 7200     1
# 1977     1
# 4011     1
# 1588     1
# 1647     1
# 1498     1
# 993      1
# 3165     1
# 3222     1
# 3297     1
# 4520     1
# 981      1
# 1968     1
# 3497     1
# 3530     1
# 4602     1
# 3000     1
# 2986     1
# 5704     1
# 3695     1
# 1390     1
# 3346     1
# 5972     1
# 2491     1
# 1564     1
# 4367     1
# 2962     1
# Name: Ccm, dtype: int64
# #######################################################
# Different values and count for column : City
# Number of unique values : 6
# Zuzwil        1072
# Porrentruy      13
# Sursee           9
# Safenwil         4
# Basel            3
# St. Gallen       2
# Name: City, dtype: int64
# #######################################################
# Different values and count for column : Co2EmissionText
# Number of unique values : 195
# 350 g/km    36
# 333 g/km    30
# 309 g/km    29
# 355 g/km    18
# 340 g/km    16
# 288 g/km    16
# 378 g/km    16
# 400 g/km    15
# 440 g/km    14
# 346 g/km    13
# 328 g/km    13
# 370 g/km    13
# 357 g/km    13
# 295 g/km    11
# 326 g/km    11
# 495 g/km    11
# 304 g/km    11
# 320 g/km    11
# 358 g/km     9
# 270 g/km     9
# 299 g/km     9
# 324 g/km     9
# 310 g/km     9
# 276 g/km     9
# 374 g/km     8
# 335 g/km     8
# 317 g/km     8
# 499 g/km     8
# 290 g/km     8
# 292 g/km     7
#             ..
# 389 g/km     1
# 450 g/km     1
# 204 g/km     1
# 196 g/km     1
# 138 g/km     1
# 260 g/km     1
# 312 g/km     1
# 289 g/km     1
# 205 g/km     1
# 284 g/km     1
# 208 g/km     1
# 360 g/km     1
# 220 g/km     1
# 443 g/km     1
# 267 g/km     1
# 211 g/km     1
# 293 g/km     1
# 311 g/km     1
# 184 g/km     1
# 472 g/km     1
# 398 g/km     1
# 271 g/km     1
# 174 g/km     1
# 490 g/km     1
# 264 g/km     1
# 376 g/km     1
# 234 g/km     1
# 173 g/km     1
# 250 g/km     1
# 261 g/km     1
# Name: Co2EmissionText, dtype: int64
# #######################################################
# Different values and count for column : ConditionTypeText
# Number of unique values : 4
# Occasion         1059
# Oldtimer           18
# Neu                17
# Vorführmodell       9
# Name: ConditionTypeText, dtype: int64
# #######################################################
# Different values and count for column : ConsumptionRatingText
# Number of unique values : 6
# G    636
# F      6
# D      4
# E      3
# C      2
# Name: ConsumptionRatingText, dtype: int64
# #######################################################
# Different values and count for column : ConsumptionTotalText
# Number of unique values : 131
# 12.9 l/100km    38
# 14.6 l/100km    34
# 13.9 l/100km    26
# 14.0 l/100km    26
# 12.0 l/100km    23
# 15.7 l/100km    23
# 14.8 l/100km    22
# 14.2 l/100km    21
# 14.9 l/100km    21
# 13.5 l/100km    20
# 12.5 l/100km    18
# 13.4 l/100km    18
# 11.5 l/100km    17
# 14.3 l/100km    17
# 12.1 l/100km    16
# 9.9 l/100km     15
# 12.6 l/100km    14
# 15.8 l/100km    13
# 14.4 l/100km    13
# 12.7 l/100km    13
# 19.3 l/100km    12
# 17.5 l/100km    12
# 11.8 l/100km    12
# 13.6 l/100km    12
# 12.3 l/100km    11
# 9.7 l/100km     11
# 11.9 l/100km     9
# 11.7 l/100km     8
# 20.8 l/100km     8
# 21.8 l/100km     8
#                 ..
# 15.2 l/100km     2
# 8.9 l/100km      2
# 15.4 l/100km     2
# 17.7 l/100km     2
# 10.2 l/100km     2
# 15.3 l/100km     2
# 19.7 l/100km     1
# 15.5 l/100km     1
# 5.3 l/100km      1
# 5.1 l/100km      1
# 6.9 l/100km      1
# 20.5 l/100km     1
# 7.6 l/100km      1
# 18.9 l/100km     1
# 19.1 l/100km     1
# 5.8 l/100km      1
# 6.7 l/100km      1
# 7.2 l/100km      1
# 18.8 l/100km     1
# 8.7 l/100km      1
# 8.8 l/100km      1
# 22.9 l/100km     1
# 6.4 l/100km      1
# 11.0 l/100km     1
# 19.5 l/100km     1
# 6.5 l/100km      1
# 7.5 l/100km      1
# 5.4 l/100km      1
# 19.0 l/100km     1
# 7.3 l/100km      1
# Name: ConsumptionTotalText, dtype: int64
# #######################################################
# Different values and count for column : Doors
# Number of unique values : 5
# 2    571
# 4    271
# 5    202
# 3     47
# 0     12
# Name: Doors, dtype: int64
# #######################################################
# Different values and count for column : DriveTypeText
# Number of unique values : 4
# Hinterradantrieb    688
# Allrad              339
# Vorderradantrieb     52
# Name: DriveTypeText, dtype: int64
# #######################################################
# Different values and count for column : FirstRegMonth
# Number of unique values : 13
# 3     140
# 1     129
# 4     113
# 6     111
# 7     107
# 5     107
# 2      82
# 9      70
# 11     66
# 10     65
# 8      65
# 12     45
# 0       3
# Name: FirstRegMonth, dtype: int64
# #######################################################
# Different values and count for column : FirstRegYear
# Number of unique values : 53
# 2002    94
# 2003    90
# 2008    61
# 2000    59
# 2004    59
# 2007    57
# 2001    57
# 2006    56
# 1999    48
# 1998    48
# 2005    46
# 1996    37
# 1997    34
# 2009    32
# 2010    29
# 2012    27
# 2011    24
# 1995    23
# 1993    15
# 2013    14
# 1974    12
# 1994    12
# 1992    12
# 1990    11
# 1982    11
# 1981    10
# 1984     9
# 1983     9
# 1991     8
# 2014     8
# 1972     7
# 2015     7
# 1971     7
# 1978     7
# 1980     6
# 1977     6
# 1973     6
# 1985     6
# 1986     5
# 1976     5
# 1989     5
# 1987     4
# 1979     3
# 1970     3
# 1988     3
# 1969     3
# 1968     2
# 1967     1
# 1955     1
# 2016     1
# 1966     1
# 1961     1
# 1957     1
# Name: FirstRegYear, dtype: int64
# #######################################################
# Different values and count for column : FuelTypeText
# Number of unique values : 5
# Benzin            1059
# Diesel              28
# Benzin/Elektro       1
# Bioethanol           1
# Name: FuelTypeText, dtype: int64
# #######################################################
# Different values and count for column : Hp
# Number of unique values : 204
# 450    49
# 500    40
# 420    38
# 306    37
# 400    36
# 320    32
# 300    30
# 580    28
# 0      25
# 560    24
# 286    23
# 150    20
# 517    18
# 170    17
# 612    17
# 380    16
# 231    15
# 525    15
# 390    15
# 394    15
# 360    14
# 200    14
# 476    13
# 354    13
# 193    12
# 347    12
# 272    11
# 224    11
# 507    10
# 367     9
#        ..
# 305     1
# 147     1
# 88      1
# 168     1
# 440     1
# 211     1
# 118     1
# 156     1
# 167     1
# 550     1
# 396     1
# 512     1
# 255     1
# 345     1
# 40      1
# 575     1
# 422     1
# 68      1
# 571     1
# 296     1
# 660     1
# 192     1
# 295     1
# 650     1
# 121     1
# 57      1
# 325     1
# 84      1
# 201     1
# 736     1
# Name: Hp, dtype: int64
# #######################################################
# Different values and count for column : InteriorColorText
# Number of unique values : 13
# schwarz       561
# beige         141
# grau          110
# mehrfarbig     62
# anthrazit      48
# braun          41
# blau           34
# rot            22
# grün            6
# bordeaux        6
# weiss           5
# silber          1
# Name: InteriorColorText, dtype: int64
# #######################################################
# Different values and count for column : Km
# Number of unique values : 711
# 5000      7
# 29000     7
# 45000     6
# 49900     6
# 100       6
# 29800     6
# 34000     6
# 62000     5
# 34500     5
# 42000     5
# 26800     5
# 38000     5
# 41000     5
# 51000     5
# 28000     5
# 43000     5
# 42500     4
# 46000     4
# 48300     4
# 500       4
# 37000     4
# 16000     4
# 12000     4
# 8000      4
# 32000     4
# 33600     4
# 39000     4
# 15000     4
# 36700     4
# 20000     4
#          ..
# 76200     1
# 50900     1
# 86900     1
# 22100     1
# 126200    1
# 1200      1
# 103800    1
# 133500    1
# 69100     1
# 68700     1
# 15100     1
# 82000     1
# 39900     1
# 10        1
# 45200     1
# 71700     1
# 29100     1
# 83600     1
# 6900      1
# 80400     1
# 143700    1
# 68200     1
# 49200     1
# 19720     1
# 118000    1
# 110200    1
# 56400     1
# 90000     1
# 222300    1
# 112800    1
# Name: Km, dtype: int64
# #######################################################
# Different values and count for column : Properties
# Number of unique values : 7
# "Ab MFK"                              959
# "Ab MFK", "Tuning"                     37
# "Ab MFK", "Direkt-/Parallelimport"     28
# "Rennwagen"                             4
# "Direkt-/Parallelimport"                3
# "Tuning"                                3
# Name: Properties, dtype: int64
# #######################################################
# Different values and count for column : Seats
# Number of unique values : 8
# 5    473
# 2    303
# 4    287
# 0     31
# 3      3
# 1      2
# 6      2
# 7      2
# Name: Seats, dtype: int64
# #######################################################
# Different values and count for column : TransmissionTypeText
# Number of unique values : 9
# Automat                           306
# Schaltgetriebe manuell            242
# Automat sequentiell               205
# Automatik-Getriebe                128
# Automatisiertes Schaltgetriebe    126
# Schaltgetriebe                     83
# Automat stufenlos                   2
# Automat stufenlos, sequentiell      1
# Name: TransmissionTypeText, dtype: int64

# %% [markdown]
# ## Analysis and Processing column by column
#
# ### MakeText & ModelText & TypeName & TypeNameFull
#
# They all look OK, nothing to normalize, the only thing is that the case is sometimes lower and sometimes upper

# %% [markdown]
# ### BodyColorText

# %%
list_colors = supplier_data_as_table["BodyColorText"].unique()
list_colors.sort()
print(list_colors)
# Out:
# ['anthrazit' 'anthrazit mét.' 'beige' 'beige mét.' 'blau' 'blau mét.'
#  'bordeaux' 'bordeaux mét.' 'braun' 'braun mét.' 'gelb' 'gelb mét.' 'gold'
#  'gold mét.' 'grau' 'grau mét.' 'grün' 'grün mét.' 'orange' 'orange mét.'
#  'rot' 'rot mét.' 'schwarz' 'schwarz mét.' 'silber' 'silber mét.'
#  'violett mét.' 'weiss' 'weiss mét.']

# %% [markdown]
# Colors look OK, nothing to normalize, maybe in a further process we could fusion the "mét." colors with their corresponding ones (eg. "beige mét." could become "beige")
#
# ### BodyTypeText
#
# Nothing to normalize
#
# ### City
#
# Nothing to normalize

# %% [markdown]
# ### Co2EmissionText
# We check if different units are used and if the values seem coherent

# %%
# We add in the dataframe 2 columns : one with the unit of consumption and one with its value
supplier_data_as_table["Co2EmissionValue"] = np.NaN
supplier_data_as_table.loc[supplier_data_as_table["Co2EmissionText"].notnull(), "Co2EmissionValue"] = supplier_data_as_table[supplier_data_as_table["Co2EmissionText"].notnull()].apply(axis=1, func= lambda x: float(x["Co2EmissionText"].split(" ")[0]))

supplier_data_as_table["Co2EmissionUnit"] = np.NaN
supplier_data_as_table.loc[supplier_data_as_table["Co2EmissionText"].notnull(), "Co2EmissionUnit"] = supplier_data_as_table[supplier_data_as_table["Co2EmissionText"].notnull()].apply(axis=1, func= lambda x: x["Co2EmissionText"].split(" ")[1])

# %%
# We check how many units are used
supplier_data_as_table["Co2EmissionUnit"].unique()
# Out:
# array(['g/km', nan], dtype=object)

# %% [markdown]
# Only the unit 'g/km' is used

# %%
min_co2 = supplier_data_as_table["Co2EmissionValue"].min()
max_co2 = supplier_data_as_table["Co2EmissionValue"].max()
print("The ConsumptionTotal column is between {} and {}".format(min_co2, max_co2))
# Out:
# The ConsumptionTotal column is between 127.0 and 575.0

# %% [markdown]
# Everything looks OK, nothing to normalize

# %% [markdown]
# ### ConditionTypeText
# Nothing to normalize
#
# ### ConsumptionRatingText
# Nothing to normalize

# %% [markdown]
# ### ConsumptionTotalText
# We check if different units are used and if the values seem coherent

# %%
# We add in the dataframe 2 columns : one with the unit of consumption and one with its value
supplier_data_as_table["ConsumptionValue"] = np.NaN
supplier_data_as_table.loc[supplier_data_as_table["ConsumptionTotalText"].notnull(), "ConsumptionValue"] = supplier_data_as_table[supplier_data_as_table["ConsumptionTotalText"].notnull()].apply(axis=1, func= lambda x: float(x["ConsumptionTotalText"].split(" ")[0]))

supplier_data_as_table["ConsumptionUnit"] = np.NaN
supplier_data_as_table.loc[supplier_data_as_table["ConsumptionTotalText"].notnull(), "ConsumptionUnit"] = supplier_data_as_table[supplier_data_as_table["ConsumptionTotalText"].notnull()].apply(axis=1, func= lambda x: x["ConsumptionTotalText"].split(" ")[1])

# %%
# We check how many units are used
supplier_data_as_table["ConsumptionUnit"].unique()
# Out:
# array(['l/100km', nan], dtype=object)

# %% [markdown]
# Only the unit 'l/100km' is used

# %%
min_cons = supplier_data_as_table["ConsumptionValue"].min()
max_cons = supplier_data_as_table["ConsumptionValue"].max()
print("The ConsumptionTotal column is between {} and {}".format(min_cons, max_cons))
# Out:
# The ConsumptionTotal column is between 5.1 and 24.9

# %% [markdown]
# Everything looks OK, nothing to normalize
#
# ### Doors
# Let find out what are the cars with 0 door

# %%
supplier_data_as_table[supplier_data_as_table["Doors"] == '0'].head()
# Out:
# Attribute Names      ID   MakeText    ModelText             ModelTypeText  \
# 111              1103.0  DE TOMASO      PANTERA                   PANTERA
# 118              1110.0  CHEVROLET    Silverado  Silverado 2500HD 6.6l V8
# 142              1132.0     JAGUAR       XJ 220                    XJ 220
# 226               174.0    RENAULT       ALPINE       ALPINE A310 1600 VG
# 425               364.0      LOTUS  Super Seven           Super Seven HKT
#
# Attribute Names        TypeName                        TypeNameFull  \
# 111                         NaN                   DE TOMASO PANTERA
# 118              2500HD 6.6l V8  CHEVROLET Silverado 2500HD 6.6l V8
# 142                         NaN                       JAGUAR XJ 220
# 226                A310 1600 VG         RENAULT ALPINE A310 1600 VG
# 425                         HKT               LOTUS Super Seven HKT
#
# Attribute Names BodyColorText BodyTypeText   Ccm    City       ...         Hp  \
# 111                     weiss    Limousine  5752  Zuzwil       ...          0
# 118                     weiss      Pick-up     0  Zuzwil       ...          0
# 142                     weiss        Coupé  3497  Zuzwil       ...        550
# 226                 blau mét.    Limousine  1647  Zuzwil       ...          0
# 425                 grau mét.    Cabriolet  1781  Zuzwil       ...        225
#
# Attribute Names InteriorColorText     Km Properties Seats  \
# 111                       schwarz  68100        NaN     2
# 118                    mehrfarbig  34500   "Ab MFK"     5
# 142                          grau  25000   "Ab MFK"     2
# 226                     anthrazit  59800   "Ab MFK"     0
# 425                       schwarz  26800   "Ab MFK"     0
#
# Attribute Names TransmissionTypeText Co2EmissionValue Co2EmissionUnit  \
# 111                   Schaltgetriebe              NaN             NaN
# 118               Automatik-Getriebe              NaN             NaN
# 142                   Schaltgetriebe              NaN             NaN
# 226                   Schaltgetriebe              NaN             NaN
# 425                              NaN              NaN             NaN
#
# Attribute Names ConsumptionValue ConsumptionUnit
# 111                          NaN             NaN
# 118                          NaN             NaN
# 142                          NaN             NaN
# 226                          NaN             NaN
# 425                          NaN             NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# It seems that the 0 value means that we don't know how many doors are in these cars.
# Also it is preferable to replace the 0 by NaN

# %%
supplier_data_as_table.loc[supplier_data_as_table["Doors"] == '0', "Doors"] = np.NaN

# %% [markdown]
# ### DriveTypeText
# Nothing to normalize
#
# ### FirstRegMonth
# Like the doors it seem better to replace the values 0 by NaN

# %%
supplier_data_as_table.loc[supplier_data_as_table["FirstRegMonth"] == '0', "FirstRegMonth"] = np.NaN

# %% [markdown]
# ### FirstRegYear
# We check that the years are within a realistic range

# %%
supplier_data_as_table["FirstRegYear"] = supplier_data_as_table["FirstRegYear"].astype(int)
min_year = supplier_data_as_table["FirstRegYear"].min()
max_year = supplier_data_as_table["FirstRegYear"].max()
print("The FirstRegYear column is between {} and {}".format(min_year, max_year))
# Out:
# The FirstRegYear column is between 1955 and 2016

# %% [markdown]
# All the years seem correct, nothing to normalize
#
# ### FuelTypeText
# Nothing to normalize
#
# ### HP
# Like the doors it seem better to replace the values 0 by NaN

# %%
supplier_data_as_table.loc[supplier_data_as_table["Hp"] == '0', "Hp"] = np.NaN

# %%
supplier_data_as_table["Hp"] = supplier_data_as_table["Hp"].astype(float)
min_hp = supplier_data_as_table["Hp"].min()
max_hp = supplier_data_as_table["Hp"].max()
print("The HP column is between {} and {}".format(min_hp, max_hp))
# Out:
# The HP column is between 29.0 and 800.0

# %% [markdown]
# The range of HP seem reasonable

# %% [markdown]
# ### InteriorColorText
# Nothing to normalize
#
# ### Km
# We check that the kilometers are within a reasonable range

# %%
supplier_data_as_table["Km"] = supplier_data_as_table["Km"].astype(int)
min_km = supplier_data_as_table["Km"].min()
max_km = supplier_data_as_table["Km"].max()
print("The Km column is between {} and {}".format(min_km, max_km))
# Out:
# The Km column is between 1 and 316200

# %% [markdown]
# ### Properties
# Nothing to normalize

# %% [markdown]
# ### Seats
# Like the doors it seem better to replace the values 0 by NaN

# %%
supplier_data_as_table.loc[supplier_data_as_table["Seats"] == '0', "Seats"] = np.NaN

# %% [markdown]
# ### TransmissionTypeText
# Here we could normalize this attribute, because some different values mean the same (eg "Automat" and "Automatik-Getriebe").
#
# Only 4 values seem necessary : Automat, Schaltgetriebe, Automat sequentiell and Automstufenlos.
#
# Below a dictionary defining the new values :

# %%
transmission_aggregation = {
    'Automat': 'Automat',
    'Schaltgetriebe': 'Schaltgetriebe',
    'Schaltgetriebe manuell': 'Schaltgetriebe',
    'Automat sequentiell': 'Automat sequentiell',
    'Automatik-Getriebe': 'Automat',
    'Automatisiertes Schaltgetriebe': 'Automat',
    'Automat stufenlos': 'Automat stufenlos',
    'Automat stufenlos, sequentiell': 'stufenlos',
     np.NaN: np.NaN}

# %%
# Create a new column with the normalized values of the column TransmissionTypeText
supplier_data_as_table["NewTransmissionTypeText"] = supplier_data_as_table.apply(axis=1, func=lambda x: transmission_aggregation[x["TransmissionTypeText"]])
supplier_data_as_table.head(30)
# Out:
# Attribute Names      ID       MakeText    ModelText  \
# 0                   1.0  MERCEDES-BENZ        E 320
# 1                 100.0        FERRARI         F360
# 2                1000.0     ALFA ROMEO           8C
# 3                1001.0            BMW         2002
# 4                1003.0           AUDI           A8
# 5                1004.0    LAMBORGHINI     GALLARDO
# 6                1005.0  MERCEDES-BENZ          280
# 7                1006.0  MERCEDES-BENZ       SL 320
# 8                1007.0        PORSCHE      CAYENNE
# 9                1008.0            BMW          745
# 10               1009.0        PORSCHE          911
# 11                101.0        PORSCHE          911
# 12               1010.0  MERCEDES-BENZ     E 55 AMG
# 13               1011.0           AUDI          RS6
# 14               1012.0    LAMBORGHINI       DIABLO
# 15               1014.0     ALFA ROMEO           8C
# 16               1015.0  MERCEDES-BENZ       ML 400
# 17               1016.0             VW         GOLF
# 18               1017.0             VW        JETTA
# 19               1018.0  MERCEDES-BENZ          190
# 20               1019.0       WIESMANN        COUPE
# 21                102.0        PORSCHE          911
# 22               1020.0            BMW           Z4
# 23               1021.0        RENAULT  Alpine A110
# 24               1022.0       MASERATI     COUPÉ GT
# 25               1023.0        RENAULT       ALPINE
# 26               1024.0           AUDI           A8
# 27               1025.0      CHEVROLET     CORVETTE
# 28               1026.0         TOYOTA      COROLLA
# 29               1027.0  MERCEDES-BENZ   CLK 55 AMG
#
# Attribute Names                 ModelTypeText                      TypeName  \
# 0                      E 320 Elégance 4-Matic        E 320 Elégance 4-Matic
# 1                      F360 Modena Berlinetta        F360 Modena Berlinetta
# 2                                          8C                           NaN
# 3                                  2002 Turbo                         Turbo
# 4                              A8 4.2 quattro                A8 4.2 quattro
# 5                   Gallardo 5.0 V10 Coupé SE     Gallardo 5.0 V10 Coupé SE
# 6                           280 3.5 V8 Cabrio                 3.5 V8 Cabrio
# 7                                      SL 320                        SL 320
# 8                               Cayenne Turbo                 Cayenne Turbo
# 9                                        745i                          745i
# 10                           911 Carrera 2 RS              911 Carrera 2 RS
# 11               911 Carrera 4 Cabrio TECHART  911 Carrera 4 Cabrio TECHART
# 12                        E 55 AMG Avantgarde           E 55 AMG Avantgarde
# 13                          RS6 Avant quattro             RS6 Avant quattro
# 14                              Diablo 5.7 VT                 Diablo 5.7 VT
# 15                                   8C Coupé                         Coupé
# 16                                 ML 400 CDI                    ML 400 CDI
# 17                          Golf 2.0 TFSI GTI             Golf 2.0 TFSI GTI
# 18                      Jetta 2.0 TDI Comfort         Jetta 2.0 TDI Comfort
# 19                           190 E 2.5-16 ABS              190 E 2.5-16 ABS
# 20                                     GT MF5                        GT MF5
# 21                           911 Turbo Cabrio              911 Turbo Cabrio
# 22                                 Z4 M Coupé                    Z4 M Coupé
# 23                          Alpine A110 1300S                         1300S
# 24                                   Coupé GT                      Coupé GT
# 25                             ALPINE 1600 VF                       1600 VF
# 26                             A8 4.2 quattro                A8 4.2 quattro
# 27                               Corvette Z06                  Corvette Z06
# 28                      Corolla 1600 GTi TC16         Corolla 1600 GTi TC16
# 29                      CLK 55 AMG Avantgarde         CLK 55 AMG Avantgarde
#
# Attribute Names                           TypeNameFull BodyColorText  \
# 0                 MERCEDES-BENZ E 320 Elégance 4-Matic     anthrazit
# 1                       FERRARI F360 Modena Berlinetta     blau mét.
# 2                                        ALFA ROMEO 8C   silber mét.
# 3                                       BMW 2002 Turbo   silber mét.
# 4                                  AUDI A8 4.2 quattro   silber mét.
# 5                LAMBORGHINI Gallardo 5.0 V10 Coupé SE   silber mét.
# 6                      MERCEDES-BENZ 280 3.5 V8 Cabrio   silber mét.
# 7                                 MERCEDES-BENZ SL 320   silber mét.
# 8                                PORSCHE Cayenne Turbo   silber mét.
# 9                                             BMW 745i   silber mét.
# 10                            PORSCHE 911 Carrera 2 RS   silber mét.
# 11                PORSCHE 911 Carrera 4 Cabrio TECHART     blau mét.
# 12                   MERCEDES-BENZ E 55 AMG Avantgarde   silber mét.
# 13                              AUDI RS6 Avant quattro   silber mét.
# 14                           LAMBORGHINI Diablo 5.7 VT   silber mét.
# 15                                 ALFA ROMEO 8C Coupé   silber mét.
# 16                            MERCEDES-BENZ ML 400 CDI   silber mét.
# 17                                VW Golf 2.0 TFSI GTI   silber mét.
# 18                            VW Jetta 2.0 TDI Comfort   silber mét.
# 19                      MERCEDES-BENZ 190 E 2.5-16 ABS   silber mét.
# 20                                     WIESMANN GT MF5   silber mét.
# 21                            PORSCHE 911 Turbo Cabrio     blau mét.
# 22                                      BMW Z4 M Coupé   silber mét.
# 23                           RENAULT Alpine A110 1300S   silber mét.
# 24                                   MASERATI Coupé GT   silber mét.
# 25                              RENAULT ALPINE 1600 VF   silber mét.
# 26                                 AUDI A8 4.2 quattro   silber mét.
# 27                              CHEVROLET Corvette Z06   silber mét.
# 28                        TOYOTA Corolla 1600 GTi TC16   silber mét.
# 29                 MERCEDES-BENZ CLK 55 AMG Avantgarde   silber mét.
#
# Attribute Names        BodyTypeText   Ccm        City  \
# 0                         Limousine  3199      Zuzwil
# 1                             Coupé  3586      Zuzwil
# 2                         Cabriolet  4691  Porrentruy
# 3                         Limousine  1977      Zuzwil
# 4                         Limousine  4172      Zuzwil
# 5                             Coupé  4961      Zuzwil
# 6                         Cabriolet  3499      Sursee
# 7                         Cabriolet  3199      Zuzwil
# 8                SUV / Geländewagen  4511      Zuzwil
# 9                         Limousine  4398      Zuzwil
# 10                            Coupé  3598      Zuzwil
# 11                        Cabriolet  3387      Zuzwil
# 12                        Limousine  5439      Zuzwil
# 13                            Kombi  4172      Zuzwil
# 14                            Coupé  5707      Zuzwil
# 15                            Coupé  4691      Zuzwil
# 16               SUV / Geländewagen  3996      Zuzwil
# 17                        Limousine  1984      Zuzwil
# 18                        Limousine  1968      Zuzwil
# 19                        Limousine  2497      Zuzwil
# 20                            Coupé  4999      Zuzwil
# 21                        Cabriolet  3800      Zuzwil
# 22                            Coupé  3246      Zuzwil
# 23                            Coupé  1296      Zuzwil
# 24                            Coupé  4244      Zuzwil
# 25                            Coupé  1605      Zuzwil
# 26                        Limousine  4172      Zuzwil
# 27                            Coupé  7011      Zuzwil
# 28                            Coupé  1587      Zuzwil
# 29                            Coupé  5439      Zuzwil
#
# Attribute Names           ...            InteriorColorText      Km  \
# 0                         ...                         grau   31900
# 1                         ...                        beige   42600
# 2                         ...                      schwarz   23900
# 3                         ...                      schwarz   97100
# 4                         ...                      schwarz   66300
# 5                         ...                      schwarz   20000
# 6                         ...                        beige     500
# 7                         ...                      schwarz  156800
# 8                         ...                      schwarz   91600
# 9                         ...                      schwarz   27600
# 10                        ...                      schwarz  123000
# 11                        ...                      schwarz   80400
# 12                        ...                      schwarz   53800
# 13                        ...                      schwarz   47400
# 14                        ...                      schwarz   14990
# 15                        ...                      schwarz   37000
# 16                        ...                      schwarz   87800
# 17                        ...                         grau   87000
# 18                        ...                         grau   33500
# 19                        ...                      schwarz  198000
# 20                        ...                      schwarz   34600
# 21                        ...                   mehrfarbig   52000
# 22                        ...                      schwarz   10900
# 23                        ...                      schwarz    9999
# 24                        ...                        braun   62300
# 25                        ...                      schwarz   42940
# 26                        ...                         grau   35100
# 27                        ...                      schwarz   24000
# 28                        ...                      schwarz  101400
# 29                        ...                      schwarz   79500
#
# Attribute Names                          Properties Seats  \
# 0                                          "Ab MFK"     5
# 1                                          "Ab MFK"     2
# 2                                          "Ab MFK"   NaN
# 3                                          "Ab MFK"     4
# 4                                          "Ab MFK"     5
# 5                                          "Ab MFK"     2
# 6                                               NaN     4
# 7                                          "Ab MFK"     2
# 8                                          "Ab MFK"     5
# 9                                          "Ab MFK"     5
# 10                                         "Ab MFK"     2
# 11                                         "Ab MFK"     4
# 12                                         "Ab MFK"     5
# 13                                         "Ab MFK"     5
# 14                                         "Ab MFK"     2
# 15                                              NaN   NaN
# 16                                         "Ab MFK"     5
# 17                                         "Ab MFK"     5
# 18                                         "Ab MFK"     5
# 19                                         "Ab MFK"     5
# 20                                         "Ab MFK"     2
# 21               "Ab MFK", "Direkt-/Parallelimport"     4
# 22                               "Ab MFK", "Tuning"     2
# 23                                         "Ab MFK"   NaN
# 24                                         "Ab MFK"     4
# 25                                         "Ab MFK"     4
# 26                                         "Ab MFK"     5
# 27                                         "Ab MFK"     2
# 28                                         "Ab MFK"     4
# 29                                         "Ab MFK"     4
#
# Attribute Names            TransmissionTypeText Co2EmissionValue  \
# 0                                       Automat            275.0
# 1                Automatisiertes Schaltgetriebe            440.0
# 2                            Automatik-Getriebe              NaN
# 3                                Schaltgetriebe              NaN
# 4                                       Automat            322.0
# 5                Automatisiertes Schaltgetriebe            400.0
# 6                                           NaN              NaN
# 7                                       Automat            297.0
# 8                                       Automat            378.0
# 9                           Automat sequentiell            276.0
# 10                       Schaltgetriebe manuell              NaN
# 11                                      Automat            304.0
# 12                          Automat sequentiell            310.0
# 13                          Automat sequentiell            350.0
# 14                       Schaltgetriebe manuell              NaN
# 15                           Automatik-Getriebe              NaN
# 16                                      Automat            288.0
# 17                       Schaltgetriebe manuell            194.0
# 18               Automatisiertes Schaltgetriebe            154.0
# 19                                      Automat              NaN
# 20               Automatisiertes Schaltgetriebe              NaN
# 21               Automatisiertes Schaltgetriebe            270.0
# 22                       Schaltgetriebe manuell            292.0
# 23                               Schaltgetriebe              NaN
# 24                           Automatik-Getriebe            400.0
# 25                               Schaltgetriebe              NaN
# 26                          Automat sequentiell            288.0
# 27                       Schaltgetriebe manuell            350.0
# 28                       Schaltgetriebe manuell              NaN
# 29                                      Automat            281.0
#
# Attribute Names Co2EmissionUnit  ConsumptionValue ConsumptionUnit  \
# 0                          g/km              11.5         l/100km
# 1                          g/km              19.3         l/100km
# 2                           NaN               NaN             NaN
# 3                           NaN               NaN             NaN
# 4                          g/km              13.5         l/100km
# 5                          g/km              17.0         l/100km
# 6                           NaN               NaN             NaN
# 7                          g/km              12.5         l/100km
# 8                          g/km              15.7         l/100km
# 9                          g/km              11.4         l/100km
# 10                          NaN               NaN             NaN
# 11                         g/km              12.0         l/100km
# 12                         g/km              12.9         l/100km
# 13                         g/km              14.6         l/100km
# 14                          NaN               NaN             NaN
# 15                          NaN               NaN             NaN
# 16                         g/km              10.9         l/100km
# 17                         g/km               8.1         l/100km
# 18                         g/km               5.8         l/100km
# 19                          NaN               NaN             NaN
# 20                          NaN              14.1         l/100km
# 21                         g/km              11.5         l/100km
# 22                         g/km              12.1         l/100km
# 23                          NaN               NaN             NaN
# 24                         g/km              17.5         l/100km
# 25                          NaN               NaN             NaN
# 26                         g/km              12.0         l/100km
# 27                         g/km              14.7         l/100km
# 28                          NaN               NaN             NaN
# 29                         g/km              11.7         l/100km
#
# Attribute Names  NewTransmissionTypeText
# 0                                Automat
# 1                                Automat
# 2                                Automat
# 3                         Schaltgetriebe
# 4                                Automat
# 5                                Automat
# 6                                    NaN
# 7                                Automat
# 8                                Automat
# 9                    Automat sequentiell
# 10                        Schaltgetriebe
# 11                               Automat
# 12                   Automat sequentiell
# 13                   Automat sequentiell
# 14                        Schaltgetriebe
# 15                               Automat
# 16                               Automat
# 17                        Schaltgetriebe
# 18                               Automat
# 19                               Automat
# 20                               Automat
# 21                               Automat
# 22                        Schaltgetriebe
# 23                        Schaltgetriebe
# 24                               Automat
# 25                        Schaltgetriebe
# 26                   Automat sequentiell
# 27                        Schaltgetriebe
# 28                        Schaltgetriebe
# 29                               Automat
#
# [30 rows x 30 columns]

# %% [markdown]
# # 2 - Data Extraction
# Lets keep only the columns that contain useful information for the target format.
#
# The useful columns are : BodyColorText, BodyTypeText, Properties, Seats, ConditionTypeText, City, MakeText, Km, ModelText, ModelTypeText

# %%
supplier_data_extracted = supplier_data_as_table[['ID', 'MakeText', 'Km', 'ModelText', 'ModelTypeText', 'BodyColorText', 'BodyTypeText', 'Properties', 'Seats', 'ConditionTypeText', 'City']]

# %%
supplier_data_extracted.head()
# Out:
# Attribute Names      ID       MakeText     Km ModelText  \
# 0                   1.0  MERCEDES-BENZ  31900     E 320
# 1                 100.0        FERRARI  42600      F360
# 2                1000.0     ALFA ROMEO  23900        8C
# 3                1001.0            BMW  97100      2002
# 4                1003.0           AUDI  66300        A8
#
# Attribute Names           ModelTypeText BodyColorText BodyTypeText Properties  \
# 0                E 320 Elégance 4-Matic     anthrazit    Limousine   "Ab MFK"
# 1                F360 Modena Berlinetta     blau mét.        Coupé   "Ab MFK"
# 2                                    8C   silber mét.    Cabriolet   "Ab MFK"
# 3                            2002 Turbo   silber mét.    Limousine   "Ab MFK"
# 4                        A8 4.2 quattro   silber mét.    Limousine   "Ab MFK"
#
# Attribute Names Seats ConditionTypeText        City
# 0                   5          Occasion      Zuzwil
# 1                   2          Occasion      Zuzwil
# 2                 NaN          Occasion  Porrentruy
# 3                   4          Occasion      Zuzwil
# 4                   5          Occasion      Zuzwil

# %% [markdown]
# # 3 - Data Integration
# ## Mapping Definition

# %%
color_mapping = {
    'anthrazit': 'Gray',
    'anthrazit mét.': 'Gray',
    'beige': 'Beige',
    'beige mét.': 'Beige',
    'blau': 'Blue',
    'blau mét.': 'Blue',
    'bordeaux': 'Other',
    'bordeaux mét.': 'Other',
    'braun': 'Brown',
    'braun mét.': 'Brown',
    'gelb': 'Yellow',
    'gelb mét.': 'Yellow',
    'gold': 'Gold',
    'gold mét.': 'Gold',
    'grau': 'Gray',
    'grau mét.': 'Gray',
    'grün': 'Green',
    'grün mét.': 'Green',
    'orange': 'Orange',
    'orange mét.': 'Orange',
    'rot': 'Red',
    'rot mét.': 'Red',
    'schwarz': 'Black',
    'schwarz mét.': 'Black',
    'silber': 'Gray',
    'silber mét.': 'Gray',
    'violett mét.': 'Purple',
    'weiss': 'White',
    'weiss mét.': 'White',
    np.NaN: np.NaN}

type_mapping = {
    'Coupé' : 'Coupé',
    'Limousine' : 'Other',
    'Cabriolet' : 'Convertible / Roadster',
    'Kombi' : 'Other',
    'SUV / Geländewagen' : 'SUV',
    'Kleinwagen' : 'Other',
    'Kompaktvan / Minivan' : 'Station Wagon',
    'Pick-up' : 'Other',
    'Sattelschlepper' : 'Other',
    'Wohnkabine' : 'Other',
    np.NaN: np.NaN}
    
condition_mapping = {
    'Occasion': 'Used',
    'Oldtimer': 'Used',
    'Neu': 'New',
    'Vorführmodell': 'New',
    np.NaN: np.NaN}

# %% [markdown]
# ## Rule to compute the car type
# We can use serveral attributes to find out the car type as defined in the database.
#
# Here the rule we can set :
#
# - If the field "Properties" contains the string "Tuning" then the value of the carType is "Custom"
#
# - Else if the field "Seats" equal to "1" then the value of the carType is "Single Seater"
#
# - Else we use the type mapping dictionary

# %% [markdown]
# ## Rule to compute the make
# To compute the make of one car we check if it exists in the database.
# - If so we use the case used in the database
# - If not we use directly the make provided by the supplier but we warn the user that this make is not an existing make of the database

# %% [markdown]
# ## Rule to compute the model
#
# We the make, the model and the model variant of the database to compute the model of the cars from the json.
#
# Indeed the models in the json are usually more precised than the models in the database. Also we need to find out at what model of the database corresponds the model of the json.
#
# - For a model of the json : we split it by space, to get a list of unique word. Then we compute all the combination of this words
# - For the model of the database we concatenate the model and the model variant, and we delete the spaces.
#
# Then we check if one combination of the words is contained in the concatenation of the models and variants of the car of the same make :
# - If so we return the model of this car.
# - If not we use directly the model provided by the supplier but we warn the user that this model is not an existing model of the database

# %% [markdown]
# ## Rule to compute de model variant

# %% [markdown]
# The model variant in the supplier data sometimes repeat the model at the beginning : also to avoid information duplication we remove from the variant the model when it is present at the beginning of the variant
